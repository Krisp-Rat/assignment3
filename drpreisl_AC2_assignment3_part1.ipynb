# %%
import gymnasium as gym
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from helper_functions import reward_print, print_state_dict
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "cpu"
)
device = "cpu"
print(device)
CUDA_LAUNCH_BLOCKING=1
# Out:
# cpu

# %%
# AC2 algorithm 
class A2C:
    def __init__(self, env):
        self.actor = Actor(env)
        self.critic = Critic(self.actor.env.observation_space.shape[0])
    
    # Main training loop
    def train(self, episodes, gamma, greedy=False):
        total_reward = [0] * episodes
        for i in range(episodes):
            step = rewards = 0
            done = False     
            state, info = self.actor.env.reset()
            state = torch.tensor(state)
            action_list = []
            while not done:
                # Actor makes decision 
                # Environment returns state and reward
                next_state, reward, done, action = self.actor.act(state, greedy)
                next_state = torch.tensor(next_state)#.todevice
                # Critic evaluates action 
                adv = self.critic.evaluate(state, next_state, reward, gamma)
                # Pass that value to the Actor
                self.actor.evaluation(action, adv, state)
                #action_list += action
                state = next_state
                step += 1
                rewards += reward
                
                # Before it is done
                if done:
                    reward = -10
                    next_state = None
                    adv = self.critic.evaluate(state, next_state, reward, gamma ** step)
                    self.actor.evaluation(action, adv, state)
                
            total_reward[i] = rewards
            print("Episode:", i, " Reward", rewards)
            #print(action_list)
        self.actor.env.close()
        return total_reward

               
    def save(self, filename):
        with open("pickles/" + filename + "actor.pickle", 'wb') as file:
            pickle.dump(self.actor.policy_net.state_dict(), file)
        with open("pickles/" + filename + "critic.pickle", 'wb') as file:
            pickle.dump(self.critic.policy_net.state_dict(), file)

# %%
# Actor thread
class ActorNet(nn.Module):  
    def __init__(self, obs, act):
        super(ActorNet, self).__init__()
        self.layer1 = nn.Linear(obs, 128)
        self.layer2 = nn.Linear(128, act)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.softmax(self.layer2(x), dim=-1)
        return x
        

class Actor:
    def __init__(self, env):
        self.env_type = env
        self.env = gym.make(env)
        self.policy_net = ActorNet(self.env.observation_space.shape[0], self.env.action_space.n)
        self.optimizer = optim.AdamW(self.policy_net.parameters(), amsgrad=True, lr=.001)
    
    def act(self, state, greedy):
        # Get the weights from the policy net
        weights = self.policy_net(state)
        # if greedy get max-arg 
        if greedy: 
            action = torch.argmax(weights)
        # Use multinomial to select probability / action
        else:
            action = torch.multinomial(weights, 1)
        # Run and return the action 
        state, reward, terminated, truncated, _ = self.env.step(action.item())
        return state, reward, terminated or truncated, action

    
    def evaluation(self, action, advantage, state):
        # Get the weights from the policy 
        weight = self.policy_net(state)
        # Calculate the log probability with the weights of the 
        # current state and action and then use the adv to get the loss 
        prob = torch.distributions.Categorical(weight).log_prob(action)  
        loss = -1 * prob * advantage.detach()
        # back prop
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
    
    
    def change_render(self, render):
        if render:
            self.env = gym.make(self.env_type, render_mode="human", max_episode_steps=200)
        else: 
            self.env = gym.make(self.env_type, max_episode_steps=200)

# %%
# Critic thread
class CriticNet(nn.Module):  
    def __init__(self, obs):
        super(CriticNet, self).__init__()
        self.layer1 = nn.Linear(obs, 128)
        self.layer2 = nn.Linear(128, 1)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        return  self.layer2(x)


class Critic:
    def __init__(self, obs):
        
        self.policy_net = CriticNet(obs)
        self.optimizer = optim.AdamW(self.policy_net.parameters(),amsgrad=True, lr=.001)
    
    
    def evaluate(self, state, next_state, reward, gamma):
        # Get Qvalue and next Qvalue from policy         
        Qvalue = self.policy_net(state)
        if next_state is not None:
            next_Qvalue = self.policy_net(next_state)
        else: 
            next_Qvalue = 0
        
        # Calculate the TD and advantage for the next action
        TD = reward + (gamma * next_Qvalue)
        # print(next_Qvalue)
        adv = TD - Qvalue
        TD = torch.tensor([TD])
        loss_function = nn.MSELoss()
        loss = loss_function(Qvalue, TD)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        return adv

# %%
# AC2 Agent for Cart Pole
environment = 'CartPole-v1'
agent = A2C(environment)

episodes = 400
gamma = .99

agent.actor.change_render(True)

# Main training session
total_rewards = agent.train(episodes, gamma)
print("Best reward: ", max(total_rewards))
agent.save("drpreisl_CartPole")
reward_print(total_rewards, episodes, "Cart Pole")

# Greedy run 
agent.actor.change_render(True)
total_greedy_rewards = agent.train(11, gamma, greedy=True)
reward_print(total_greedy_rewards, 10, "greedy")
# Out:
# Episode: 0  Reward 13.0
# Episode: 1  Reward 10.0
# Episode: 2  Reward 15.0
# Episode: 3  Reward 23.0
# Episode: 4  Reward 33.0
# Episode: 5  Reward 20.0
# Episode: 6  Reward 40.0
# Episode: 7  Reward 10.0
# Episode: 8  Reward 21.0
# Episode: 9  Reward 10.0
# Episode: 10  Reward 9.0
# Episode: 11  Reward 18.0
# Episode: 12  Reward 14.0
# Episode: 13  Reward 25.0
# Episode: 14  Reward 11.0
# Episode: 15  Reward 18.0
# Episode: 16  Reward 13.0
# Episode: 17  Reward 10.0
# Episode: 18  Reward 16.0
# Episode: 19  Reward 18.0
# Episode: 20  Reward 10.0
# Episode: 21  Reward 13.0
# Episode: 22  Reward 44.0
# Episode: 23  Reward 9.0
# Episode: 24  Reward 12.0
# Episode: 25  Reward 36.0
# Episode: 26  Reward 16.0
# Episode: 27  Reward 11.0
# Episode: 28  Reward 11.0
# Episode: 29  Reward 12.0
# Episode: 30  Reward 18.0
# Episode: 31  Reward 22.0
# Episode: 32  Reward 13.0
# Episode: 33  Reward 11.0
# Episode: 34  Reward 15.0
# Episode: 35  Reward 12.0
# Episode: 36  Reward 11.0
# Episode: 37  Reward 13.0
# Episode: 38  Reward 12.0
# Episode: 39  Reward 9.0
# Episode: 40  Reward 12.0
# Episode: 41  Reward 11.0
# Episode: 42  Reward 11.0
# Episode: 43  Reward 10.0
# Episode: 44  Reward 10.0
# Episode: 45  Reward 11.0
# Episode: 46  Reward 11.0
# Episode: 47  Reward 12.0
# Episode: 48  Reward 12.0
# Episode: 49  Reward 12.0
# Episode: 50  Reward 10.0
# Episode: 51  Reward 12.0
# Episode: 52  Reward 13.0
# Episode: 53  Reward 14.0
# Episode: 54  Reward 8.0
# Episode: 55  Reward 12.0
# Episode: 56  Reward 11.0
# Episode: 57  Reward 12.0
# Episode: 58  Reward 35.0
# Episode: 59  Reward 8.0
# Episode: 60  Reward 12.0
# Episode: 61  Reward 37.0
# Episode: 62  Reward 26.0
# Episode: 63  Reward 16.0
# Episode: 64  Reward 35.0
# Episode: 65  Reward 17.0
# Episode: 66  Reward 16.0
# Episode: 67  Reward 13.0
# Episode: 68  Reward 21.0
# Episode: 69  Reward 10.0
# Episode: 70  Reward 26.0
# Episode: 71  Reward 12.0
# Episode: 72  Reward 12.0
# Episode: 73  Reward 17.0
# Episode: 74  Reward 13.0
# Episode: 75  Reward 15.0
# Episode: 76  Reward 29.0
# Episode: 77  Reward 10.0
# Episode: 78  Reward 20.0
# Episode: 79  Reward 12.0
# Episode: 80  Reward 11.0
# Episode: 81  Reward 37.0
# Episode: 82  Reward 54.0
# Episode: 83  Reward 10.0
# Episode: 84  Reward 9.0
# Episode: 85  Reward 9.0
# Episode: 86  Reward 19.0
# Episode: 87  Reward 14.0
# Episode: 88  Reward 21.0
# Episode: 89  Reward 37.0
# Episode: 90  Reward 22.0
# Episode: 91  Reward 16.0
# Episode: 92  Reward 15.0
# Episode: 93  Reward 17.0
# Episode: 94  Reward 11.0
# Episode: 95  Reward 16.0
# Episode: 96  Reward 28.0
# Episode: 97  Reward 31.0
# Episode: 98  Reward 51.0
# Episode: 99  Reward 16.0
# Episode: 100  Reward 18.0
# Episode: 101  Reward 18.0
# Episode: 102  Reward 21.0
# Episode: 103  Reward 63.0
# Episode: 104  Reward 33.0
# Episode: 105  Reward 46.0
# Episode: 106  Reward 20.0
# Episode: 107  Reward 68.0
# Episode: 108  Reward 72.0
# Episode: 109  Reward 23.0
# Episode: 110  Reward 36.0
# Episode: 111  Reward 22.0
# Episode: 112  Reward 20.0
# Episode: 113  Reward 18.0
# Episode: 114  Reward 19.0
# Episode: 115  Reward 25.0
# Episode: 116  Reward 19.0
# Episode: 117  Reward 16.0
# Episode: 118  Reward 13.0
# Episode: 119  Reward 19.0
# Episode: 120  Reward 16.0
# Episode: 121  Reward 24.0
# Episode: 122  Reward 46.0
# Episode: 123  Reward 44.0
# Episode: 124  Reward 80.0
# Episode: 125  Reward 42.0
# Episode: 126  Reward 188.0
# Episode: 127  Reward 37.0
# Episode: 128  Reward 62.0
# Episode: 129  Reward 35.0
# Episode: 130  Reward 20.0
# Episode: 131  Reward 22.0
# Episode: 132  Reward 32.0
# Episode: 133  Reward 40.0
# Episode: 134  Reward 55.0
# Episode: 135  Reward 57.0
# Episode: 136  Reward 31.0
# Episode: 137  Reward 102.0
# Episode: 138  Reward 70.0
# Episode: 139  Reward 54.0
# Episode: 140  Reward 28.0
# Episode: 141  Reward 30.0
# Episode: 142  Reward 75.0
# Episode: 143  Reward 37.0
# Episode: 144  Reward 65.0
# Episode: 145  Reward 57.0
# Episode: 146  Reward 50.0
# Episode: 147  Reward 54.0
# Episode: 148  Reward 71.0
# Episode: 149  Reward 36.0
# Episode: 150  Reward 52.0
# Episode: 151  Reward 46.0
# Episode: 152  Reward 86.0
# Episode: 153  Reward 40.0
# Episode: 154  Reward 35.0
# Episode: 155  Reward 29.0
# Episode: 156  Reward 34.0
# Episode: 157  Reward 32.0
# Episode: 158  Reward 40.0
# Episode: 159  Reward 28.0
# Episode: 160  Reward 23.0
# Episode: 161  Reward 35.0
# Episode: 162  Reward 26.0
# Episode: 163  Reward 22.0
# Episode: 164  Reward 27.0
# Episode: 165  Reward 27.0
# Episode: 166  Reward 21.0
# Episode: 167  Reward 15.0
# Episode: 168  Reward 20.0
# Episode: 169  Reward 21.0
# Episode: 170  Reward 21.0
# Episode: 171  Reward 31.0
# Episode: 172  Reward 22.0
# Episode: 173  Reward 33.0
# Episode: 174  Reward 23.0
# Episode: 175  Reward 23.0
# Episode: 176  Reward 22.0
# Episode: 177  Reward 38.0
# Episode: 178  Reward 19.0
# Episode: 179  Reward 20.0
# Episode: 180  Reward 20.0
# Episode: 181  Reward 16.0
# Episode: 182  Reward 15.0
# Episode: 183  Reward 20.0
# Episode: 184  Reward 29.0
# Episode: 185  Reward 19.0
# Episode: 186  Reward 25.0
# Episode: 187  Reward 22.0
# Episode: 188  Reward 25.0
# Episode: 189  Reward 16.0
# Episode: 190  Reward 32.0
# Episode: 191  Reward 24.0
# Episode: 192  Reward 33.0
# Episode: 193  Reward 26.0
# Episode: 194  Reward 19.0
# Episode: 195  Reward 32.0
# Episode: 196  Reward 23.0
# Episode: 197  Reward 24.0
# Episode: 198  Reward 22.0
# Episode: 199  Reward 27.0
# Episode: 200  Reward 27.0
# Episode: 201  Reward 23.0
# Episode: 202  Reward 21.0
# Episode: 203  Reward 34.0
# Episode: 204  Reward 20.0
# Episode: 205  Reward 26.0
# Episode: 206  Reward 20.0
# Episode: 207  Reward 26.0
# Episode: 208  Reward 27.0
# Episode: 209  Reward 35.0
# Episode: 210  Reward 30.0
# Episode: 211  Reward 30.0
# Episode: 212  Reward 24.0
# Episode: 213  Reward 30.0
# Episode: 214  Reward 31.0
# Episode: 215  Reward 33.0
# Episode: 216  Reward 24.0
# Episode: 217  Reward 83.0
# Episode: 218  Reward 75.0
# Episode: 219  Reward 25.0
# Episode: 220  Reward 45.0
# Episode: 221  Reward 30.0
# Episode: 222  Reward 29.0
# Episode: 223  Reward 31.0
# Episode: 224  Reward 36.0
# Episode: 225  Reward 26.0
# Episode: 226  Reward 27.0
# Episode: 227  Reward 29.0
# Episode: 228  Reward 26.0
# Episode: 229  Reward 33.0
# Episode: 230  Reward 29.0
# Episode: 231  Reward 38.0
# Episode: 232  Reward 35.0
# Episode: 233  Reward 25.0
# Episode: 234  Reward 68.0
# Episode: 235  Reward 24.0
# Episode: 236  Reward 41.0
# Episode: 237  Reward 29.0
# Episode: 238  Reward 37.0
# Episode: 239  Reward 29.0
# Episode: 240  Reward 30.0
# Episode: 241  Reward 31.0
# Episode: 242  Reward 59.0
# Episode: 243  Reward 25.0
# Episode: 244  Reward 29.0
# Episode: 245  Reward 83.0
# Episode: 246  Reward 30.0
# Episode: 247  Reward 42.0
# Episode: 248  Reward 38.0
# Episode: 249  Reward 31.0
# Episode: 250  Reward 47.0
# Episode: 251  Reward 36.0
# Episode: 252  Reward 38.0
# Episode: 253  Reward 33.0
# Episode: 254  Reward 27.0
# Episode: 255  Reward 31.0
# Episode: 256  Reward 41.0
# Episode: 257  Reward 36.0
# Episode: 258  Reward 27.0
# Episode: 259  Reward 27.0
# Episode: 260  Reward 53.0
# Episode: 261  Reward 31.0
# Episode: 262  Reward 44.0
# Episode: 263  Reward 24.0
# Episode: 264  Reward 45.0
# Episode: 265  Reward 23.0
# Episode: 266  Reward 37.0
# Episode: 267  Reward 44.0
# Episode: 268  Reward 24.0
# Episode: 269  Reward 34.0
# Episode: 270  Reward 49.0
# Episode: 271  Reward 29.0
# Episode: 272  Reward 40.0
# Episode: 273  Reward 35.0
# Episode: 274  Reward 43.0
# Episode: 275  Reward 24.0
# Episode: 276  Reward 83.0
# Episode: 277  Reward 36.0
# Episode: 278  Reward 59.0
# Episode: 279  Reward 73.0
# Episode: 280  Reward 23.0
# Episode: 281  Reward 59.0
# Episode: 282  Reward 26.0
# Episode: 283  Reward 53.0
# Episode: 284  Reward 30.0
# Episode: 285  Reward 33.0
# Episode: 286  Reward 34.0
# Episode: 287  Reward 32.0
# Episode: 288  Reward 23.0
# Episode: 289  Reward 35.0
# Episode: 290  Reward 42.0
# Episode: 291  Reward 25.0
# Episode: 292  Reward 24.0
# Episode: 293  Reward 23.0
# Episode: 294  Reward 27.0
# Episode: 295  Reward 33.0
# Episode: 296  Reward 30.0
# Episode: 297  Reward 31.0
# Episode: 298  Reward 30.0
# Episode: 299  Reward 19.0
# Episode: 300  Reward 35.0
# Episode: 301  Reward 22.0
# Episode: 302  Reward 30.0
# Episode: 303  Reward 23.0
# Episode: 304  Reward 23.0
# Episode: 305  Reward 28.0
# Episode: 306  Reward 27.0
# Episode: 307  Reward 31.0
# Episode: 308  Reward 27.0
# Episode: 309  Reward 37.0
# Episode: 310  Reward 27.0
# Episode: 311  Reward 25.0
# Episode: 312  Reward 20.0
# Episode: 313  Reward 28.0
# Episode: 314  Reward 41.0
# Episode: 315  Reward 29.0
# Episode: 316  Reward 35.0
# Episode: 317  Reward 31.0
# Episode: 318  Reward 26.0
# Episode: 319  Reward 44.0
# Episode: 320  Reward 30.0
# Episode: 321  Reward 35.0
# Episode: 322  Reward 31.0
# Episode: 323  Reward 24.0
# Episode: 324  Reward 24.0
# Episode: 325  Reward 51.0
# Episode: 326  Reward 28.0
# Episode: 327  Reward 22.0
# Episode: 328  Reward 27.0
# Episode: 329  Reward 40.0
# Episode: 330  Reward 33.0
# Episode: 331  Reward 35.0
# Episode: 332  Reward 38.0
# Episode: 333  Reward 44.0
# Episode: 334  Reward 29.0
# Episode: 335  Reward 26.0
# Episode: 336  Reward 33.0
# Episode: 337  Reward 26.0
# Episode: 338  Reward 29.0
# Episode: 339  Reward 42.0
# Episode: 340  Reward 37.0
# Episode: 341  Reward 36.0
# Episode: 342  Reward 23.0
# Episode: 343  Reward 47.0
# Episode: 344  Reward 23.0
# Episode: 345  Reward 23.0
# Episode: 346  Reward 27.0
# Episode: 347  Reward 40.0
# Episode: 348  Reward 39.0
# Episode: 349  Reward 42.0
# Episode: 350  Reward 40.0
# Episode: 351  Reward 50.0
# Episode: 352  Reward 62.0
# Episode: 353  Reward 28.0
# Episode: 354  Reward 44.0
# Episode: 355  Reward 41.0
# Episode: 356  Reward 33.0
# Episode: 357  Reward 24.0
# Episode: 358  Reward 28.0
# Episode: 359  Reward 28.0
# Episode: 360  Reward 44.0
# Episode: 361  Reward 25.0
# Episode: 362  Reward 59.0
# Episode: 363  Reward 60.0
# Episode: 364  Reward 37.0
# Episode: 365  Reward 51.0
# Episode: 366  Reward 41.0
# Episode: 367  Reward 25.0
# Episode: 368  Reward 24.0
# Episode: 369  Reward 54.0
# Episode: 370  Reward 35.0
# Episode: 371  Reward 28.0
# Episode: 372  Reward 32.0
# Episode: 373  Reward 24.0
# Episode: 374  Reward 43.0
# Episode: 375  Reward 47.0
# Episode: 376  Reward 37.0
# Episode: 377  Reward 33.0
# Episode: 378  Reward 39.0
# Episode: 379  Reward 23.0
# Episode: 380  Reward 29.0
# Episode: 381  Reward 29.0
# Episode: 382  Reward 26.0
# Episode: 383  Reward 31.0
# Episode: 384  Reward 53.0
# Episode: 385  Reward 61.0
# Episode: 386  Reward 35.0
# Episode: 387  Reward 37.0
# Episode: 388  Reward 43.0
# Episode: 389  Reward 26.0
# Episode: 390  Reward 35.0
# Episode: 391  Reward 34.0
# Episode: 392  Reward 44.0
# Episode: 393  Reward 27.0
# Episode: 394  Reward 46.0
# Episode: 395  Reward 43.0
# Episode: 396  Reward 63.0
# Episode: 397  Reward 25.0
# Episode: 398  Reward 60.0
# Episode: 399  Reward 32.0
# Best reward:  188.0
# Episode: 0  Reward 61.0
# Episode: 1  Reward 31.0
# Episode: 2  Reward 24.0
# Episode: 3  Reward 83.0
# Episode: 4  Reward 54.0
# Episode: 5  Reward 31.0
# Episode: 6  Reward 41.0
# Episode: 7  Reward 44.0
# Episode: 8  Reward 27.0
# Episode: 9  Reward 39.0
# Episode: 10  Reward 27.0

# %%
# Add episodes to avoid having to retrain 1000+ episodes
add_episodes = 400
agent.actor.change_render(True)

# Main training session
add_total_rewards = agent.train(add_episodes, gamma)
total_rewards += add_total_rewards
episodes += add_episodes
print("Best reward: ", max(total_rewards))
reward_print(total_rewards, episodes, "Cart Pole")

# Greedy run 
agent.actor.change_render(True)
total_greedy_rewards = agent.train(11, gamma, greedy=True)
reward_print(total_greedy_rewards, 10, "greedy")
# Out:
# Episode: 0  Reward 32.0
# Episode: 1  Reward 40.0
# Episode: 2  Reward 27.0
# Episode: 3  Reward 53.0
# Episode: 4  Reward 58.0
# Episode: 5  Reward 49.0
# Episode: 6  Reward 53.0
# Episode: 7  Reward 53.0
# Episode: 8  Reward 43.0
# Episode: 9  Reward 53.0
# Episode: 10  Reward 30.0
# Episode: 11  Reward 76.0
# Episode: 12  Reward 77.0
# Episode: 13  Reward 46.0
# Episode: 14  Reward 33.0
# Episode: 15  Reward 42.0
# Episode: 16  Reward 36.0
# Episode: 17  Reward 37.0
# Episode: 18  Reward 48.0
# Episode: 19  Reward 31.0
# Episode: 20  Reward 40.0
# Episode: 21  Reward 43.0
# Episode: 22  Reward 65.0
# Episode: 23  Reward 29.0
# Episode: 24  Reward 37.0
# Episode: 25  Reward 80.0
# Episode: 26  Reward 45.0
# Episode: 27  Reward 56.0
# Episode: 28  Reward 58.0
# Episode: 29  Reward 34.0
# Episode: 30  Reward 49.0
# Episode: 31  Reward 33.0
# Episode: 32  Reward 70.0
# Episode: 33  Reward 28.0
# Episode: 34  Reward 37.0
# Episode: 35  Reward 45.0
# Episode: 36  Reward 65.0
# Episode: 37  Reward 48.0
# Episode: 38  Reward 83.0
# Episode: 39  Reward 53.0
# Episode: 40  Reward 92.0
# Episode: 41  Reward 43.0
# Episode: 42  Reward 50.0
# Episode: 43  Reward 33.0
# Episode: 44  Reward 43.0
# Episode: 45  Reward 41.0
# Episode: 46  Reward 44.0
# Episode: 47  Reward 41.0
# Episode: 48  Reward 33.0
# Episode: 49  Reward 36.0
# Episode: 50  Reward 39.0
# Episode: 51  Reward 90.0
# Episode: 52  Reward 33.0
# Episode: 53  Reward 38.0
# Episode: 54  Reward 81.0
# Episode: 55  Reward 54.0
# Episode: 56  Reward 60.0
# Episode: 57  Reward 34.0
# Episode: 58  Reward 75.0
# Episode: 59  Reward 121.0
# Episode: 60  Reward 58.0
# Episode: 61  Reward 37.0
# Episode: 62  Reward 51.0
# Episode: 63  Reward 92.0
# Episode: 64  Reward 36.0
# Episode: 65  Reward 79.0
# Episode: 66  Reward 34.0
# Episode: 67  Reward 44.0
# Episode: 68  Reward 84.0
# Episode: 69  Reward 42.0
# Episode: 70  Reward 63.0
# Episode: 71  Reward 124.0
# Episode: 72  Reward 49.0
# Episode: 73  Reward 42.0
# Episode: 74  Reward 73.0
# Episode: 75  Reward 38.0
# Episode: 76  Reward 29.0
# Episode: 77  Reward 49.0
# Episode: 78  Reward 76.0
# Episode: 79  Reward 64.0
# Episode: 80  Reward 26.0
# Episode: 81  Reward 33.0
# Episode: 82  Reward 39.0
# Episode: 83  Reward 27.0
# Episode: 84  Reward 46.0
# Episode: 85  Reward 70.0
# Episode: 86  Reward 53.0
# Episode: 87  Reward 43.0
# Episode: 88  Reward 35.0
# Episode: 89  Reward 31.0
# Episode: 90  Reward 39.0
# Episode: 91  Reward 45.0
# Episode: 92  Reward 50.0
# Episode: 93  Reward 51.0
# Episode: 94  Reward 27.0
# Episode: 95  Reward 35.0
# Episode: 96  Reward 29.0
# Episode: 97  Reward 44.0
# Episode: 98  Reward 43.0
# Episode: 99  Reward 75.0
# Episode: 100  Reward 75.0
# Episode: 101  Reward 72.0
# Episode: 102  Reward 46.0
# Episode: 103  Reward 44.0
# Episode: 104  Reward 32.0
# Episode: 105  Reward 40.0
# Episode: 106  Reward 83.0
# Episode: 107  Reward 32.0
# Episode: 108  Reward 90.0
# Episode: 109  Reward 28.0
# Episode: 110  Reward 42.0
# Episode: 111  Reward 31.0
# Episode: 112  Reward 26.0
# Episode: 113  Reward 53.0
# Episode: 114  Reward 27.0
# Episode: 115  Reward 30.0
# Episode: 116  Reward 42.0
# Episode: 117  Reward 49.0
# Episode: 118  Reward 31.0
# Episode: 119  Reward 29.0
# Episode: 120  Reward 58.0
# Episode: 121  Reward 37.0
# Episode: 122  Reward 39.0
# Episode: 123  Reward 41.0
# Episode: 124  Reward 52.0
# Episode: 125  Reward 44.0
# Episode: 126  Reward 103.0
# Episode: 127  Reward 59.0
# Episode: 128  Reward 59.0
# Episode: 129  Reward 73.0
# Episode: 130  Reward 69.0
# Episode: 131  Reward 51.0
# Episode: 132  Reward 55.0
# Episode: 133  Reward 42.0
# Episode: 134  Reward 42.0
# Episode: 135  Reward 46.0
# Episode: 136  Reward 35.0
# Episode: 137  Reward 44.0
# Episode: 138  Reward 44.0
# Episode: 139  Reward 33.0
# Episode: 140  Reward 33.0
# Episode: 141  Reward 33.0
# Episode: 142  Reward 43.0
# Episode: 143  Reward 67.0
# Episode: 144  Reward 44.0
# Episode: 145  Reward 86.0
# Episode: 146  Reward 55.0
# Episode: 147  Reward 46.0
# Episode: 148  Reward 41.0
# Episode: 149  Reward 29.0
# Episode: 150  Reward 38.0
# Episode: 151  Reward 59.0
# Episode: 152  Reward 34.0
# Episode: 153  Reward 44.0
# Episode: 154  Reward 37.0
# Episode: 155  Reward 46.0
# Episode: 156  Reward 49.0
# Episode: 157  Reward 52.0
# Episode: 158  Reward 42.0
# Episode: 159  Reward 28.0
# Episode: 160  Reward 40.0
# Episode: 161  Reward 32.0
# Episode: 162  Reward 43.0
# Episode: 163  Reward 48.0
# Episode: 164  Reward 41.0
# Episode: 165  Reward 48.0
# Episode: 166  Reward 53.0
# Episode: 167  Reward 39.0
# Episode: 168  Reward 69.0
# Episode: 169  Reward 44.0
# Episode: 170  Reward 50.0
# Episode: 171  Reward 31.0
# Episode: 172  Reward 57.0
# Episode: 173  Reward 44.0
# Episode: 174  Reward 50.0
# Episode: 175  Reward 30.0
# Episode: 176  Reward 44.0
# Episode: 177  Reward 88.0
# Episode: 178  Reward 116.0
# Episode: 179  Reward 27.0
# Episode: 180  Reward 40.0
# Episode: 181  Reward 57.0
# Episode: 182  Reward 37.0
# Episode: 183  Reward 48.0
# Episode: 184  Reward 32.0
# Episode: 185  Reward 28.0
# Episode: 186  Reward 53.0
# Episode: 187  Reward 42.0
# Episode: 188  Reward 34.0
# Episode: 189  Reward 63.0
# Episode: 190  Reward 78.0
# Episode: 191  Reward 62.0
# Episode: 192  Reward 59.0
# Episode: 193  Reward 50.0
# Episode: 194  Reward 39.0
# Episode: 195  Reward 31.0
# Episode: 196  Reward 95.0
# Episode: 197  Reward 43.0
# Episode: 198  Reward 47.0
# Episode: 199  Reward 39.0
# Episode: 200  Reward 28.0
# Episode: 201  Reward 39.0
# Episode: 202  Reward 25.0
# Episode: 203  Reward 141.0
# Episode: 204  Reward 72.0
# Episode: 205  Reward 67.0
# Episode: 206  Reward 58.0
# Episode: 207  Reward 52.0
# Episode: 208  Reward 72.0
# Episode: 209  Reward 48.0
# Episode: 210  Reward 35.0
# Episode: 211  Reward 40.0
# Episode: 212  Reward 32.0
# Episode: 213  Reward 46.0
# Episode: 214  Reward 47.0
# Episode: 215  Reward 45.0
# Episode: 216  Reward 31.0
# Episode: 217  Reward 106.0
# Episode: 218  Reward 47.0
# Episode: 219  Reward 29.0
# Episode: 220  Reward 55.0
# Episode: 221  Reward 106.0
# Episode: 222  Reward 34.0
# Episode: 223  Reward 28.0
# Episode: 224  Reward 29.0
# Episode: 225  Reward 42.0
# Episode: 226  Reward 40.0
# Episode: 227  Reward 73.0
# Episode: 228  Reward 38.0
# Episode: 229  Reward 41.0
# Episode: 230  Reward 38.0
# Episode: 231  Reward 58.0
# Episode: 232  Reward 27.0
# Episode: 233  Reward 52.0
# Episode: 234  Reward 47.0
# Episode: 235  Reward 62.0
# Episode: 236  Reward 34.0
# Episode: 237  Reward 29.0
# Episode: 238  Reward 52.0
# Episode: 239  Reward 41.0
# Episode: 240  Reward 51.0
# Episode: 241  Reward 58.0
# Episode: 242  Reward 41.0
# Episode: 243  Reward 45.0
# Episode: 244  Reward 46.0
# Episode: 245  Reward 47.0
# Episode: 246  Reward 43.0
# Episode: 247  Reward 41.0
# Episode: 248  Reward 47.0
# Episode: 249  Reward 36.0
# Episode: 250  Reward 44.0
# Episode: 251  Reward 33.0
# Episode: 252  Reward 37.0
# Episode: 253  Reward 37.0
# Episode: 254  Reward 46.0
# Episode: 255  Reward 37.0
# Episode: 256  Reward 39.0
# Episode: 257  Reward 35.0
# Episode: 258  Reward 32.0
# Episode: 259  Reward 34.0
# Episode: 260  Reward 43.0
# Episode: 261  Reward 37.0
# Episode: 262  Reward 67.0
# Episode: 263  Reward 66.0
# Episode: 264  Reward 32.0
# Episode: 265  Reward 77.0
# Episode: 266  Reward 40.0
# Episode: 267  Reward 45.0
# Episode: 268  Reward 33.0
# Episode: 269  Reward 28.0
# Episode: 270  Reward 57.0
# Episode: 271  Reward 46.0
# Episode: 272  Reward 31.0
# Episode: 273  Reward 52.0
# Episode: 274  Reward 29.0
# Episode: 275  Reward 40.0
# Episode: 276  Reward 55.0
# Episode: 277  Reward 58.0
# Episode: 278  Reward 64.0
# Episode: 279  Reward 53.0
# Episode: 280  Reward 39.0
# Episode: 281  Reward 37.0
# Episode: 282  Reward 40.0
# Episode: 283  Reward 49.0
# Episode: 284  Reward 70.0
# Episode: 285  Reward 88.0
# Episode: 286  Reward 49.0
# Episode: 287  Reward 34.0
# Episode: 288  Reward 85.0
# Episode: 289  Reward 69.0
# Episode: 290  Reward 31.0
# Episode: 291  Reward 59.0
# Episode: 292  Reward 33.0
# Episode: 293  Reward 78.0
# Episode: 294  Reward 42.0
# Episode: 295  Reward 34.0
# Episode: 296  Reward 55.0
# Episode: 297  Reward 55.0
# Episode: 298  Reward 39.0
# Episode: 299  Reward 51.0
# Episode: 300  Reward 46.0
# Episode: 301  Reward 54.0
# Episode: 302  Reward 49.0
# Episode: 303  Reward 41.0
# Episode: 304  Reward 30.0
# Episode: 305  Reward 67.0
# Episode: 306  Reward 42.0
# Episode: 307  Reward 32.0
# Episode: 308  Reward 35.0
# Episode: 309  Reward 39.0
# Episode: 310  Reward 35.0
# Episode: 311  Reward 71.0
# Episode: 312  Reward 41.0
# Episode: 313  Reward 34.0
# Episode: 314  Reward 45.0
# Episode: 315  Reward 45.0
# Episode: 316  Reward 51.0
# Episode: 317  Reward 50.0
# Episode: 318  Reward 39.0
# Episode: 319  Reward 33.0
# Episode: 320  Reward 30.0
# Episode: 321  Reward 40.0
# Episode: 322  Reward 63.0
# Episode: 323  Reward 41.0
# Episode: 324  Reward 45.0
# Episode: 325  Reward 54.0
# Episode: 326  Reward 35.0
# Episode: 327  Reward 39.0
# Episode: 328  Reward 39.0
# Episode: 329  Reward 116.0
# Episode: 330  Reward 46.0
# Episode: 331  Reward 36.0
# Episode: 332  Reward 33.0
# Episode: 333  Reward 56.0
# Episode: 334  Reward 58.0
# Episode: 335  Reward 49.0
# Episode: 336  Reward 35.0
# Episode: 337  Reward 56.0
# Episode: 338  Reward 58.0
# Episode: 339  Reward 44.0
# Episode: 340  Reward 38.0
# Episode: 341  Reward 37.0
# Episode: 342  Reward 67.0
# Episode: 343  Reward 40.0
# Episode: 344  Reward 49.0
# Episode: 345  Reward 50.0
# Episode: 346  Reward 44.0
# Episode: 347  Reward 53.0
# Episode: 348  Reward 52.0
# Episode: 349  Reward 29.0
# Episode: 350  Reward 41.0
# Episode: 351  Reward 42.0
# Episode: 352  Reward 35.0
# Episode: 353  Reward 35.0
# Episode: 354  Reward 49.0
# Episode: 355  Reward 51.0
# Episode: 356  Reward 39.0
# Episode: 357  Reward 37.0
# Episode: 358  Reward 61.0
# Episode: 359  Reward 54.0
# Episode: 360  Reward 60.0
# Episode: 361  Reward 60.0
# Episode: 362  Reward 46.0
# Episode: 363  Reward 34.0
# Episode: 364  Reward 45.0
# Episode: 365  Reward 38.0
# Episode: 366  Reward 36.0
# Episode: 367  Reward 58.0
# Episode: 368  Reward 43.0
# Episode: 369  Reward 50.0
# Episode: 370  Reward 100.0
# Episode: 371  Reward 42.0
# Episode: 372  Reward 33.0
# Episode: 373  Reward 73.0
# Episode: 374  Reward 34.0
# Episode: 375  Reward 78.0
# Episode: 376  Reward 47.0
# Episode: 377  Reward 98.0
# Episode: 378  Reward 38.0
# Episode: 379  Reward 30.0
# Episode: 380  Reward 24.0
# Episode: 381  Reward 31.0
# Episode: 382  Reward 54.0
# Episode: 383  Reward 27.0
# Episode: 384  Reward 43.0
# Episode: 385  Reward 90.0
# Episode: 386  Reward 31.0
# Episode: 387  Reward 43.0
# Episode: 388  Reward 48.0
# Episode: 389  Reward 27.0
# Episode: 390  Reward 37.0
# Episode: 391  Reward 26.0
# Episode: 392  Reward 48.0
# Episode: 393  Reward 30.0
# Episode: 394  Reward 37.0
# Episode: 395  Reward 35.0
# Episode: 396  Reward 40.0
# Episode: 397  Reward 38.0
# Episode: 398  Reward 43.0
# Episode: 399  Reward 42.0
# Best reward:  188.0
# Episode: 0  Reward 59.0
# Episode: 1  Reward 61.0
# Episode: 2  Reward 32.0
# Episode: 3  Reward 26.0
# Episode: 4  Reward 43.0
# Episode: 5  Reward 40.0
# Episode: 6  Reward 41.0
# Episode: 7  Reward 29.0
# Episode: 8  Reward 36.0
# Episode: 9  Reward 30.0
# Episode: 10  Reward 26.0

# %%
# Prints the final graph and saves final weights

print("Average", sum(total_rewards)/ len(total_rewards))
reward_print(total_rewards, episodes, "Cart Pole")
reward_print(total_greedy_rewards, 10, "Cart Pole")
agent.save("drpreisl_CartPole")
# Out:
# Average 38.8975
